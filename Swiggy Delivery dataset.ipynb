# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
df=pd.read_csv('C:/Users/parsh/OneDrive/Desktop/Datasets/Swiggy_dataset.csv')

# %%
df.head()
# Out:
#   type      id                       name  \
# 0    F   37933     Faasos - Wraps & Rolls
# 1    F   81814                Burger King
# 2    F  107046        Mahalaxmi Pav Bhaji
# 3    F  328315                 HIIT Meals
# 4    F  108879  Jay Jalaram Parotha House
#
#                                    uuid       city         area avgRating  \
# 0  6fe9caf1-02a7-4e66-83bb-1b4ff296b683  Ahmedabad    Vastrapur       4.2
# 1  10083576-d32d-4a0e-8a82-3236ef342a19  Ahmedabad  Ellisbridge       4.2
# 2  fbfe3bfa-03fd-4708-b913-06e2c9ee9639  Ahmedabad  Ellisbridge       4.3
# 3  81ab4019-2445-4aef-aff2-04beccd641d9  Ahmedabad      Vishala        --
# 4  994e73e1-7c7c-4ad9-87e7-ecfecd4e36fa  Ahmedabad  Ellisbridge       3.9
#
#   totalRatingsString                                           cuisines  \
# 0       500+ ratings  ['Combo' 'Snacks' 'Beverages' 'Desserts' 'Indi...
# 1      1000+ ratings                           ['American' 'Fast Food']
# ...

# %%
df.shape
# Out:
# (8691, 18)

# %%
df.isnull().sum()
# Out:
# type                     0
# id                       0
# name                     0
# uuid                     3
# city                     0
# area                     0
# avgRating                0
# totalRatingsString       0
# cuisines                 0
# costForTwoStrings        0
# deliveryTime             0
# minDeliveryTime          0
# maxDeliveryTime          0
# address                  9
# locality                10
# unserviceable            6
# veg                      6
# City                  8691
# dtype: int64

# %%
df['area'].replace({'Ambavadi':'Ambawadi'},inplace=True)

# %% [markdown]
# ### Ahmedabad

# %%
df1=df[(df['city']=='Ahmedabad')]

# %%
df1
# Out:
#     type      id                         name  \
# 0      F   37933       Faasos - Wraps & Rolls
# 1      F   81814                  Burger King
# 2      F  107046          Mahalaxmi Pav Bhaji
# 3      F  328315                   HIIT Meals
# 4      F  108879    Jay Jalaram Parotha House
# ..   ...     ...                          ...
# 714    F  386004          Sher-e-punjab dhaba
# 715    F  179449  Jay Ambe Bhajipav And Pulav
# 716    F  389104          Hari Om Kathiyawadi
# 717    F   58818                Test Of Spice
# 718    F  425161     Rolls and Rolls and More
#
#                                      uuid       city         area avgRating  \
# 0    6fe9caf1-02a7-4e66-83bb-1b4ff296b683  Ahmedabad    Vastrapur       4.2
# 1    10083576-d32d-4a0e-8a82-3236ef342a19  Ahmedabad  Ellisbridge       4.2
# 2    fbfe3bfa-03fd-4708-b913-06e2c9ee9639  Ahmedabad  Ellisbridge       4.3
# 3    81ab4019-2445-4aef-aff2-04beccd641d9  Ahmedabad      Vishala        --
# ...

# %%
df1.isnull().sum()
# Out:
# type                    0
# id                      0
# name                    0
# uuid                    0
# city                    0
# area                    0
# avgRating               0
# totalRatingsString      0
# cuisines                0
# costForTwoStrings       0
# deliveryTime            0
# minDeliveryTime         0
# maxDeliveryTime         0
# address                 2
# locality                2
# unserviceable           0
# veg                     0
# City                  719
# dtype: int64

# %%
df1
# Out:
#     type      id                         name  \
# 0      F   37933       Faasos - Wraps & Rolls
# 1      F   81814                  Burger King
# 2      F  107046          Mahalaxmi Pav Bhaji
# 3      F  328315                   HIIT Meals
# 4      F  108879    Jay Jalaram Parotha House
# ..   ...     ...                          ...
# 714    F  386004          Sher-e-punjab dhaba
# 715    F  179449  Jay Ambe Bhajipav And Pulav
# 716    F  389104          Hari Om Kathiyawadi
# 717    F   58818                Test Of Spice
# 718    F  425161     Rolls and Rolls and More
#
#                                      uuid       city         area avgRating  \
# 0    6fe9caf1-02a7-4e66-83bb-1b4ff296b683  Ahmedabad    Vastrapur       4.2
# 1    10083576-d32d-4a0e-8a82-3236ef342a19  Ahmedabad  Ellisbridge       4.2
# 2    fbfe3bfa-03fd-4708-b913-06e2c9ee9639  Ahmedabad  Ellisbridge       4.3
# 3    81ab4019-2445-4aef-aff2-04beccd641d9  Ahmedabad      Vishala        --
# ...

# %%
df1.dropna()
df1.isnull().sum()
# Out:
# type                    0
# id                      0
# name                    0
# uuid                    0
# city                    0
# area                    0
# avgRating               0
# totalRatingsString      0
# cuisines                0
# costForTwoStrings       0
# deliveryTime            0
# minDeliveryTime         0
# maxDeliveryTime         0
# address                 2
# locality                2
# unserviceable           0
# veg                     0
# City                  719
# dtype: int64

# %%
df1['area'].value_counts()
# Out:
# Navrangpura             133
# Vastrapur                94
# Ellisbridge              50
# Maninagar                45
# Naranpura                30
#                        ...
# Odhav                     1
# Prahlad nagar             1
# Noble Nagar Tenament      1
# Shah-E-Alam Roja          1
# Ghodasar                  1
# Name: area, Length: 81, dtype: int64

# %%
df1.columns
# Out:
# Index(['type', 'id', 'name', 'uuid', 'city', 'area', 'avgRating',
#        'totalRatingsString', 'cuisines', 'costForTwoStrings', 'deliveryTime',
#        'minDeliveryTime', 'maxDeliveryTime', 'address', 'locality',
#        'unserviceable', 'veg', 'City'],
#       dtype='object')

# %%
df11=df1[['type', 'id', 'name', 'area','city' ,'avgRating', 'cuisines', 'costForTwoStrings', 'deliveryTime', 'minDeliveryTime', 'maxDeliveryTime', 'address', 'locality', 'unserviceable', 'veg']]

# %% [markdown]
# ### Veg Restaurant in Ahmedabad

# %%
dfveg=df1[(df1['veg']==True)]

# %%
dfveg
# Out:
#     type      id                           name  \
# 2      F  107046            Mahalaxmi Pav Bhaji
# 4      F  108879      Jay Jalaram Parotha House
# 5      F  140314          Jalaram Parotha House
# 8      F   58425  Modi Sandwich And Pizza-Paldi
# 12     F   40844                   Hocco Eatery
# ..   ...     ...                            ...
# 702    F  338386     SHREE ATALJI KHANA KHAJANA
# 706    F  451121              ANNAPURNA KITCHEN
# 707    F  418077           ASHIRWAD DINING HALL
# 712    F  191644            Chandravilas Corner
# 713    F   91536             Kamal's Restaurant
#
#                                      uuid       city          area avgRating  \
# 2    fbfe3bfa-03fd-4708-b913-06e2c9ee9639  Ahmedabad   Ellisbridge       4.3
# 4    994e73e1-7c7c-4ad9-87e7-ecfecd4e36fa  Ahmedabad   Ellisbridge       3.9
# 5    e6ba1c33-66b6-45a2-8860-6ccde126da9a  Ahmedabad         Paldi       3.9
# ...

# %%
dfveg.to_csv('C:/Users/parsh/OneDrive/Desktop/Datasets/Swiggy/Ahmedabad/VegFoodAhmedabad.csv',index=None)

# %%
df1['CostForTwo']=df1['costForTwoStrings'].astype(str).apply(lambda x : x.split(' ')[0])
df1=df1.drop(['costForTwoStrings'],axis='columns')
cols=['CostForTwo']
for col in cols:
    df1[col] = df1[col].map(lambda x: str(x).lstrip('₹')).astype(float)
# Out:
# <ipython-input-17-ad1a199bcc95>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['CostForTwo']=df1['costForTwoStrings'].astype(str).apply(lambda x : x.split(' ')[0])

# %%
df1
# Out:
#     type      id                         name  \
# 0      F   37933       Faasos - Wraps & Rolls
# 1      F   81814                  Burger King
# 2      F  107046          Mahalaxmi Pav Bhaji
# 3      F  328315                   HIIT Meals
# 4      F  108879    Jay Jalaram Parotha House
# ..   ...     ...                          ...
# 714    F  386004          Sher-e-punjab dhaba
# 715    F  179449  Jay Ambe Bhajipav And Pulav
# 716    F  389104          Hari Om Kathiyawadi
# 717    F   58818                Test Of Spice
# 718    F  425161     Rolls and Rolls and More
#
#                                      uuid       city         area avgRating  \
# 0    6fe9caf1-02a7-4e66-83bb-1b4ff296b683  Ahmedabad    Vastrapur       4.2
# 1    10083576-d32d-4a0e-8a82-3236ef342a19  Ahmedabad  Ellisbridge       4.2
# 2    fbfe3bfa-03fd-4708-b913-06e2c9ee9639  Ahmedabad  Ellisbridge       4.3
# 3    81ab4019-2445-4aef-aff2-04beccd641d9  Ahmedabad      Vishala        --
# ...

# %%
df21=df1[['name','city','area','avgRating','minDeliveryTime','CostForTwo']]

# %%
df21.drop(df21[(df21['avgRating'] =='--')].index, inplace=True)
# Out:
# C:\Users\parsh\Anaconda\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df212=df21.groupby('area')['name','city','area','avgRating','minDeliveryTime','CostForTwo'].max()
# Out:
# <ipython-input-21-ced602d2c1ba>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df212=df21.groupby('area')['name','city','area','avgRating','minDeliveryTime','CostForTwo'].max()

# %%
df212
# Out:
#                                            name       city       area  \
# area
# Acher                       Punjabi Food on way  Ahmedabad      Acher
# Ahmedabad               Shiv Shakti Kathiyawadi  Ahmedabad  Ahmedabad
# Ambawadi                   Urban Foods Ambawadi  Ahmedabad   Ambawadi
# Bhadra                     Paramount Restaurant  Ahmedabad     Bhadra
# Bodakdev                              THE ROAST  Ahmedabad   Bodakdev
# ...                                         ...        ...        ...
# Usmanpura            Zodiac by Fortune Landmark  Ahmedabad  Usmanpura
# Vastral                        The Fusion Pizza  Ahmedabad    Vastral
# Vastrapur                            Wok Palace  Ahmedabad  Vastrapur
# Vatva                    Bombay A-One Bhatiyara  Ahmedabad      Vatva
# Vishala    Shakti - The Sandwich Shop - Vishala  Ahmedabad    Vishala
#
#           avgRating  minDeliveryTime  CostForTwo
# area
# Acher           3.7               70       200.0
# ...

# %% [markdown]
# ### Cheapest food in area and name of Restaurant

# %%
df31=df21.groupby('area')['name','area','CostForTwo'].min()
# Out:
# <ipython-input-23-fcc31cb431b7>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df31=df21.groupby('area')['name','area','CostForTwo'].min()

# %%
df31
# Out:
#                                  name       area  CostForTwo
# area
# Acher             Punjabi Food on way      Acher       200.0
# Ahmedabad                 Baker's Den  Ahmedabad       150.0
# Ambawadi           Ab Chai Pe Charcha   Ambawadi       100.0
# Bhadra           Paramount Restaurant     Bhadra       750.0
# Bodakdev      Angithi By Mirch Masala   Bodakdev       300.0
# ...                               ...        ...         ...
# Usmanpura                 Mysore Cafe  Usmanpura       150.0
# Vastral    SHREE ATALJI KHANA KHAJANA    Vastral       200.0
# Vastrapur                  After Dark  Vastrapur       100.0
# Vatva          Bombay A-One Bhatiyara      Vatva       150.0
# Vishala                  Healthy Bowl    Vishala       250.0
#
# [68 rows x 3 columns]

# %%
df31.to_csv('C:/Users/parsh/OneDrive/Desktop/Datasets/Swiggy/Ahmedabad/Cheapest food Ahmedabad.csv',index=None)

# %% [markdown]
# ### Costliest food in area and name of Restaurant

# %%
df41=df21.groupby('area')['name','area','CostForTwo'].max()
# Out:
# <ipython-input-26-1d9c87bcb4cf>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df41=df21.groupby('area')['name','area','CostForTwo'].max()

# %%
df41
# Out:
#                                            name       area  CostForTwo
# area
# Acher                       Punjabi Food on way      Acher       200.0
# Ahmedabad               Shiv Shakti Kathiyawadi  Ahmedabad       550.0
# Ambawadi                   Urban Foods Ambawadi   Ambawadi       850.0
# Bhadra                     Paramount Restaurant     Bhadra       750.0
# Bodakdev                              THE ROAST   Bodakdev      1200.0
# ...                                         ...        ...         ...
# Usmanpura            Zodiac by Fortune Landmark  Usmanpura       600.0
# Vastral                        The Fusion Pizza    Vastral       500.0
# Vastrapur                            Wok Palace  Vastrapur       900.0
# Vatva                    Bombay A-One Bhatiyara      Vatva       150.0
# Vishala    Shakti - The Sandwich Shop - Vishala    Vishala       300.0
#
# [68 rows x 3 columns]

# %%
df41.to_csv('C:/Users/parsh/OneDrive/Desktop/Datasets/Swiggy/Ahmedabad/Costliest food Ahmedabad.csv',index=None)

# %%
df51 =df21.groupby('area')['name','avgRating'].max()
# Out:
# <ipython-input-29-0e3a17704c96>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df51 =df21.groupby('area')['name','avgRating'].max()

# %%
df51
# Out:
#                                            name avgRating
# area
# Acher                       Punjabi Food on way       3.7
# Ahmedabad               Shiv Shakti Kathiyawadi       4.6
# Ambawadi                   Urban Foods Ambawadi       4.5
# Bhadra                     Paramount Restaurant       4.1
# Bodakdev                              THE ROAST       4.4
# ...                                         ...       ...
# Usmanpura            Zodiac by Fortune Landmark       4.1
# Vastral                        The Fusion Pizza       4.3
# Vastrapur                            Wok Palace       4.8
# Vatva                    Bombay A-One Bhatiyara       3.7
# Vishala    Shakti - The Sandwich Shop - Vishala       4.4
#
# [68 rows x 2 columns]

# %%
df51.to_csv('C:/Users/parsh/OneDrive/Desktop/Datasets/Swiggy/Ahmedabad/Best Rated Area Wise Ahmedabad.csv',index=None)

# %% [markdown]
# ### Best Rated Restaurants with cheapest price in area

# %%
df61=pd.merge(df31, df51, on='name', how='inner')
dfk1=df21[['name']]
df61=pd.merge(df61, dfk1, on='name', how='inner')

# %%
df61
# Out:
#                                                  name                  area  \
# 0                                 Punjabi Food on way                 Acher
# 1                                Paramount Restaurant                Bhadra
# 2                                         BOSS Burger               CG Road
# 3                         Brick Kitchen - Five Petals          Chanakyapuri
# 4                                Cake Dengo Cake Shop         Drive In Road
# 5                                      Bombay Biryani            Dudheshwar
# 6                                    Comfy Restaurant              Ghodasar
# 7                                  Kamal's Restaurant           Gidc Naroda
# 8                                            Rajkamal         Girdhar Nagar
# 9                                 Kanpur Mithai House              Gomtipur
# 10                                  Surbhi Restaurant            Hatkeshwar
# ...

# %%
df61.to_csv('C:/Users/parsh/OneDrive/Desktop/Datasets/Swiggy/Ahmedabad/Best Rated & Cheapest food Ahmedabad.csv',index=None)

# %% [markdown]
# ## Bangalore

# %%
df2=df[(df['city']=='Bangalore')]

# %%
df2
# Out:
#      type      id                    name  \
# 719     F   27677              Leon Grill
# 720     F  237472     Edesia by Freshmenu
# 721     F   39066   Amulya Veg Restaurant
# 722     C   65075                  homely
# 723     F   39063          Hotel Navayuga
# ...   ...     ...                     ...
# 1660    F  159235                Fishland
# 1661    F  382537  Singh Da Punjabi Dhaba
# 1662    F  176071   Brahmins' Thatte Idli
# 1663    F  381206  Friends Chinese corner
# 1664    F  407831         The Handi Crust
#
#                                       uuid       city           area  \
# 719   d8e45e58-c4f5-4800-8784-d02ccff0cd90  Bangalore    Ashok Nagar
# 720   6a7adb7d-a642-421a-86b2-65a23594d4ac  Bangalore  Richmond Town
# 721   964bc65d-ffc3-4bb2-973a-827a9bd53f83  Bangalore   Gandhi Nagar
# 722   7e8d71fa-7a00-49db-8f0f-ce4671c19da9  Bangalore    Koramangala
# 723   6677feb1-1287-47cb-97fa-c3cbb706d41e  Bangalore       Majestic
# ...

# %%
df2.isnull().sum()
# Out:
# type                    0
# id                      0
# name                    0
# uuid                    0
# city                    0
# area                    0
# avgRating               0
# totalRatingsString      0
# cuisines                0
# costForTwoStrings       0
# deliveryTime            0
# minDeliveryTime         0
# maxDeliveryTime         0
# address                 2
# locality                0
# unserviceable           0
# veg                     0
# City                  946
# dtype: int64

# %%
df2['area'].value_counts()
# Out:
# Indiranagar              130
# Koramangala              124
# Ashok Nagar              112
# Central Bangalore         71
# Basavanagudi              54
#                         ...
# Halsuru                    1
# 3rd Block Jayanagar        1
# Basaveshwaranagar          1
# Rt Nagar                   1
# Jayanagar - 3rd Block      1
# Name: area, Length: 80, dtype: int64

# %%
df22=df2[['type', 'id', 'name', 'area','city' ,'avgRating', 'cuisines', 'costForTwoStrings', 'deliveryTime', 'minDeliveryTime', 'maxDeliveryTime', 'address', 'locality', 'unserviceable', 'veg']]

# %% [markdown]
# ### Veg Food Bangalore

# %%
df2veg=df2[(df2['veg']==True)]

# %%
df2veg
# Out:
#      type      id                        name  \
# 721     F   39066       Amulya Veg Restaurant
# 730     F   69773  The Chariot Veg Restaurant
# 737     F   47493         Hari Super Sandwich
# 740     F   40443            New Shanti Sagar
# 748     F   94759                   Roti Ghar
# ...   ...     ...                         ...
# 1645    F  219460                   Go Native
# 1647    F   54451                   La Heaven
# 1651    F  395830           SWAGAT RESTAURANT
# 1653    F   17077          Maiyas Restaurants
# 1659    F  451110                    3 Mangos
#
#                                       uuid       city                 area  \
# 721   964bc65d-ffc3-4bb2-973a-827a9bd53f83  Bangalore         Gandhi Nagar
# 730   8c0c6304-5bc3-4a75-a906-7e363a2937c9  Bangalore          Ashok Nagar
# 737   28fa6b8b-ccf7-45bb-9960-253d25859ecd  Bangalore  3rd Block Jayanagar
# 740   ec446513-e3dc-4002-9551-0dfbfee16e38  Bangalore          Rajajinagar
# ...

# %%
df2veg.to_csv('C:/Users/parsh/OneDrive/Desktop/Datasets/Swiggy/Bangalore/VegFoodBangalore.csv',index=None)

# %%
df2['CostForTwo']=df2['costForTwoStrings'].astype(str).apply(lambda x : x.split(' ')[0])
df2=df2.drop(['costForTwoStrings'],axis='columns')
cols=['CostForTwo']
for col in cols:
    df2[col] = df2[col].map(lambda x: str(x).lstrip('₹')).astype(float)
# Out:
# <ipython-input-13-1e2bc15e876a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['CostForTwo']=df2['costForTwoStrings'].astype(str).apply(lambda x : x.split(' ')[0])

# %%
df221=df2[['name','city','area','avgRating','minDeliveryTime','CostForTwo']]

# %%
df221
# Out:
#                         name       city           area avgRating  \
# 719               Leon Grill  Bangalore    Ashok Nagar       4.4
# 720      Edesia by Freshmenu  Bangalore  Richmond Town        --
# 721    Amulya Veg Restaurant  Bangalore   Gandhi Nagar        --
# 722                   homely  Bangalore    Koramangala       4.3
# 723           Hotel Navayuga  Bangalore       Majestic       4.3
# ...                      ...        ...            ...       ...
# 1660                Fishland  Bangalore   Gandhi Nagar       4.4
# 1661  Singh Da Punjabi Dhaba  Bangalore    Koramangala       3.8
# 1662   Brahmins' Thatte Idli  Bangalore   Malleshwaram       4.4
# 1663  Friends Chinese corner  Bangalore    Rajajinagar        --
# 1664         The Handi Crust  Bangalore        Halsuru        --
#
#       minDeliveryTime  CostForTwo
# 719                32       400.0
# 720                35       150.0
# 721                39       350.0
# 722                52       200.0
# ...

# %%
df221.drop(df221[(df221['avgRating'] =='--')].index, inplace=True)
# Out:
# C:\Users\parsh\Anaconda\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df222=df221.groupby('area')['name','city','area','avgRating','minDeliveryTime','CostForTwo'].max()
# Out:
# <ipython-input-17-707f03e10f25>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df222=df221.groupby('area')['name','city','area','avgRating','minDeliveryTime','CostForTwo'].max()

# %%
df222
# Out:
#                                                      name       city  \
# area
# 3rd Block Jayanagar                   Hari Super Sandwich  Bangalore
# Adugodi              Salt - Indian Restaurant Bar & Grill  Bangalore
# Armane Nagar                                      Sattvam  Bangalore
# Ashok Nagar                                     Wow! Momo  Bangalore
# Azad Nagar                    Hotel Bilal Biriyani Centre  Bangalore
# ...                                                   ...        ...
# Vasanth Nagar                             The Food Corner  Bangalore
# Victoria Layout                              Krispy Kreme  Bangalore
# Vijayanagar                              Swathi Greenland  Bangalore
# Viveka Nagar                                Maven Kitchen  Bangalore
# Wilson Garden                      NAMMA KUDLA RESTAURANT  Bangalore
#
#                                     area avgRating  minDeliveryTime  \
# area
# ...

# %% [markdown]
# ### Cheapest food in area and name of Restaurant

# %%
df311=df221.groupby('area')['name','area','CostForTwo'].min()
# Out:
# <ipython-input-19-80bc5e79d439>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df311=df221.groupby('area')['name','area','CostForTwo'].min()

# %%
df311
# Out:
#                                             name                 area  \
# area
# 3rd Block Jayanagar          Hari Super Sandwich  3rd Block Jayanagar
# Adugodi                  Dhishoom -Dhaba by Salt              Adugodi
# Armane Nagar                      Kailash Parbat         Armane Nagar
# Ashok Nagar                       Airlines Hotel          Ashok Nagar
# Azad Nagar           Hotel Bilal Biriyani Centre           Azad Nagar
# ...                                          ...                  ...
# Vasanth Nagar                        CHINESE HOT        Vasanth Nagar
# Victoria Layout         Hyderabad Biryaani House      Victoria Layout
# Vijayanagar                Durga Chats club road          Vijayanagar
# Viveka Nagar                       Maven Kitchen         Viveka Nagar
# Wilson Garden                            A2B Veg        Wilson Garden
#
#                      CostForTwo
# area
# 3rd Block Jayanagar       100.0
# Adugodi                   250.0
# ...

# %%
df311.to_csv('C:/Users/parsh/OneDrive/Desktop/Datasets/Swiggy/Bangalore/Cheapest food Bangalore.csv',index=None)

# %% [markdown]
# ### Costliest food in area and name of Restaurant

# %%
df411=df221.groupby('area')['name','area','CostForTwo'].max()
# Out:
# <ipython-input-22-4c08870f7130>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df411=df221.groupby('area')['name','area','CostForTwo'].max()

# %%
df411
# Out:
#                                                      name  \
# area
# 3rd Block Jayanagar                   Hari Super Sandwich
# Adugodi              Salt - Indian Restaurant Bar & Grill
# Armane Nagar                                      Sattvam
# Ashok Nagar                                     Wow! Momo
# Azad Nagar                    Hotel Bilal Biriyani Centre
# ...                                                   ...
# Vasanth Nagar                             The Food Corner
# Victoria Layout                              Krispy Kreme
# Vijayanagar                              Swathi Greenland
# Viveka Nagar                                Maven Kitchen
# Wilson Garden                      NAMMA KUDLA RESTAURANT
#
#                                     area  CostForTwo
# area
# 3rd Block Jayanagar  3rd Block Jayanagar       100.0
# Adugodi                          Adugodi      1300.0
# Armane Nagar                Armane Nagar      1200.0
# ...

# %%
df411.to_csv('C:/Users/parsh/OneDrive/Desktop/Datasets/Swiggy/Bangalore/Costliest food Bangalore.csv',index=None)

# %% [markdown]
# ### GoodRating Restaurants

# %%
df511 =df221.groupby('area')['name','avgRating'].max()
# Out:
# <ipython-input-55-5122e18c3547>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df511 =df221.groupby('area')['name','avgRating'].max()

# %%
df511
# Out:
#                                                      name avgRating
# area
# 3rd Block Jayanagar                   Hari Super Sandwich         4
# Adugodi              Salt - Indian Restaurant Bar & Grill       4.4
# Armane Nagar                                      Sattvam       4.2
# Ashok Nagar                                     Wow! Momo       4.9
# Azad Nagar                    Hotel Bilal Biriyani Centre       3.9
# ...                                                   ...       ...
# Vasanth Nagar                             The Food Corner       4.5
# Victoria Layout                              Krispy Kreme       4.7
# Vijayanagar                              Swathi Greenland       4.4
# Viveka Nagar                                Maven Kitchen       4.6
# Wilson Garden                      NAMMA KUDLA RESTAURANT       4.2
#
# [65 rows x 2 columns]

# %%
df511.to_csv('C:/Users/parsh/OneDrive/Desktop/Datasets/Swiggy/Bangalore/Best Rated Area Wise Bangalore.csv',index=None)

# %% [markdown]
# ### Best Rated Restaurants with cheapest price in area

# %%
df611=pd.merge(df311, df511, on='name', how='inner')
dfk11=df221[['name','area']]
df611=pd.merge(df611, dfk11, on='name', how='inner')

# %%
df611
# Out:
#                              name  CostForTwo avgRating                   area
# 0             Hari Super Sandwich       100.0         4    3rd Block Jayanagar
# 1             Hari Super Sandwich       100.0         4            Ashok Nagar
# 2     Hotel Bilal Biriyani Centre       180.0       3.9             Azad Nagar
# 3                        7 Plates       350.0       4.3            Benson Town
# 4                 Sendhoor Coffee       200.0       4.3       Cambridge layout
# 5              California Burrito       250.0       4.5       Central Banglore
# 6                   ZED THE BAKER       500.0         4      Central Bengalore
# 7                   Biryani Blues       400.0       4.2          Church Street
# 8     Khan Saheb Grills and Rolls       300.0       4.3      Commercial Street
# 9    Altaf's Chillies Restaurants       250.0       4.3             Cooke Town
# 10               Vidyarthi Bhavan       150.0       4.3          Gandhi Bazaar
# ...

# %%
df611.to_csv('C:/Users/parsh/OneDrive/Desktop/Datasets/Swiggy/Bangalore/Best Rated & Cheapest food Bangalore.csv',index=None)
